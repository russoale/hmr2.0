# %% [markdown]
# # Inspect Datasets

# %%
import os
import sys
print(sys.executable, sys.version)
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import trimesh

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf 

from glob import glob
from os.path import join, abspath
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

# for local import 
sys.path.append(abspath('..'))

from main.config import Config
from main.dataset import Dataset
from main.smpl import Smpl

from trimesh_renderer import TrimeshRenderer
from vis_util import draw_2d_on_image, show_3d_pose, show_2d_pose
# Out:
# /home/mmc-user/.virtualenvs/hmr2-notebook/bin/python3 3.6.8 (default, Oct  7 2019, 12:59:55)
# [GCC 8.3.0]

# %%
class DastasetConfig(Config):
    DATA_DIR = join('/', 'data', 'ssd1', 'russales', 'new_records')
    DATASETS = ['coco', 'lsp', 'lsp_ext', 'mpii', 'coco', 'mpii_3d', 'h36m']
    SMPL_DATASETS = ['cmu', 'joint_lim']
    TRANS_MAX = 0
    # max value of scale jitter
    SCALE_MAX = 1.
    # min value of scale jitter
    SCALE_MIN = 1.
    
# class Config is implemented as singleton, inizialize subclass first!
config = DastasetConfig()

# %%
tf_record_dirs = [join(config.DATA_DIR, dataset, '*_train.tfrecord') for dataset in config.DATASETS]
tf_records = [tf_record for tf_records in sorted([glob(f) for f in tf_record_dirs]) for tf_record in tf_records]

# %%
tf_records
# Out:
# ['/data/ssd1/russales/new_records/coco/000_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/001_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/002_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/003_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/004_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/005_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/006_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/007_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/008_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/009_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/010_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/011_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/012_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/013_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/014_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/015_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/016_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/017_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/018_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/019_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/020_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/021_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/022_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/023_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/024_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/025_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/026_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/027_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/028_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/029_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/030_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/031_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/032_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/033_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/034_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/035_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/036_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/037_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/038_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/039_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/040_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/041_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/042_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/043_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/044_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/045_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/046_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/047_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/048_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/049_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/050_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/051_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/052_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/053_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/054_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/055_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/056_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/057_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/058_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/059_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/060_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/061_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/062_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/063_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/064_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/065_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/066_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/067_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/068_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/069_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/070_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/071_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/072_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/073_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/074_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/075_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/076_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/077_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/078_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/079_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/080_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/081_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/082_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/083_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/084_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/085_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/086_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/087_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/088_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/089_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/090_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/091_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/092_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/093_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/094_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/095_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/096_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/097_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/098_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/099_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/100_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/101_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/102_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/103_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/104_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/105_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/106_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/107_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/108_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/109_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/110_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/111_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/112_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/113_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/114_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/115_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/116_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/117_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/118_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/119_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/120_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/121_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/122_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/123_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/124_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/125_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/126_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/127_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/128_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/129_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/130_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/131_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/132_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/133_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/134_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/135_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/136_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/137_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/138_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/139_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/140_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/141_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/142_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/143_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/144_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/145_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/146_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/147_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/148_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/149_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/150_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/151_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/152_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/153_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/154_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/155_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/156_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/157_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/158_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/159_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/160_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/161_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/162_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/163_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/164_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/165_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/166_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/167_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/168_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/169_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/170_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/171_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/172_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/173_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/174_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/175_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/176_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/177_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/178_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/179_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/180_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/181_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/182_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/183_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/184_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/185_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/186_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/187_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/188_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/189_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/190_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/191_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/192_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/193_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/194_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/195_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/196_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/197_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/198_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/199_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/200_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/201_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/202_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/203_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/204_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/205_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/206_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/207_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/208_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/209_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/210_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/211_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/212_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/213_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/214_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/215_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/216_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/217_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/218_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/219_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/220_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/221_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/222_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/223_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/224_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/225_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/226_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/227_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/228_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/229_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/230_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/231_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/232_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/233_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/000_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/001_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/002_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/003_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/004_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/005_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/006_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/007_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/008_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/009_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/010_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/011_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/012_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/013_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/014_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/015_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/016_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/017_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/018_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/019_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/020_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/021_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/022_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/023_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/024_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/025_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/026_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/027_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/028_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/029_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/030_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/031_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/032_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/033_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/034_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/035_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/036_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/037_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/038_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/039_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/040_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/041_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/042_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/043_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/044_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/045_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/046_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/047_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/048_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/049_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/050_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/051_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/052_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/053_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/054_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/055_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/056_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/057_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/058_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/059_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/060_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/061_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/062_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/063_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/064_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/065_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/066_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/067_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/068_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/069_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/070_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/071_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/072_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/073_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/074_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/075_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/076_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/077_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/078_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/079_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/080_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/081_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/082_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/083_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/084_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/085_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/086_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/087_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/088_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/089_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/090_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/091_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/092_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/093_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/094_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/095_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/096_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/097_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/098_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/099_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/100_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/101_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/102_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/103_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/104_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/105_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/106_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/107_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/108_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/109_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/110_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/111_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/112_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/113_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/114_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/115_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/116_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/117_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/118_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/119_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/120_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/121_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/122_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/123_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/124_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/125_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/126_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/127_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/128_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/129_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/130_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/131_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/132_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/133_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/134_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/135_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/136_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/137_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/138_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/139_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/140_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/141_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/142_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/143_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/144_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/145_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/146_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/147_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/148_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/149_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/150_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/151_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/152_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/153_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/154_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/155_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/156_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/157_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/158_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/159_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/160_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/161_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/162_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/163_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/164_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/165_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/166_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/167_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/168_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/169_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/170_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/171_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/172_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/173_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/174_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/175_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/176_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/177_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/178_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/179_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/180_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/181_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/182_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/183_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/184_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/185_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/186_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/187_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/188_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/189_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/190_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/191_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/192_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/193_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/194_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/195_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/196_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/197_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/198_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/199_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/200_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/201_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/202_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/203_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/204_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/205_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/206_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/207_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/208_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/209_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/210_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/211_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/212_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/213_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/214_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/215_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/216_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/217_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/218_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/219_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/220_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/221_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/222_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/223_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/224_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/225_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/226_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/227_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/228_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/229_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/230_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/231_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/232_train.tfrecord',
#  '/data/ssd1/russales/new_records/coco/233_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/000_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/001_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/002_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/003_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/004_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/005_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/006_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/007_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/008_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/009_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/010_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/011_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/012_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/013_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/014_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/015_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/016_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/017_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/018_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/019_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/020_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/021_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/022_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/023_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/024_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/025_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/026_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/027_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/028_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/029_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/030_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/031_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/032_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/033_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/034_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/035_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/036_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/037_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/038_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/039_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/040_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/041_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/042_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/043_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/044_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/045_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/046_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/047_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/048_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/049_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/050_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/051_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/052_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/053_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/054_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/055_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/056_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/057_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/058_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/059_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/060_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/061_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/062_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/063_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/064_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/065_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/066_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/067_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/068_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/069_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/070_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/071_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/072_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/073_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/074_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/075_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/076_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/077_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/078_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/079_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/080_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/081_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/082_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/083_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/084_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/085_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/086_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/087_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/088_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/089_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/090_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/091_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/092_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/093_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/094_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/095_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/096_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/097_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/098_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/099_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/100_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/101_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/102_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/103_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/104_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/105_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/106_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/107_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/108_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/109_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/110_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/111_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/112_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/113_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/114_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/115_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/116_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/117_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/118_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/119_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/120_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/121_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/122_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/123_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/124_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/125_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/126_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/127_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/128_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/129_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/130_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/131_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/132_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/133_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/134_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/135_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/136_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/137_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/138_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/139_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/140_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/141_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/142_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/143_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/144_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/145_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/146_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/147_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/148_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/149_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/150_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/151_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/152_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/153_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/154_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/155_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/156_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/157_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/158_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/159_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/160_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/161_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/162_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/163_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/164_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/165_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/166_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/167_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/168_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/169_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/170_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/171_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/172_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/173_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/174_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/175_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/176_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/177_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/178_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/179_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/180_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/181_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/182_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/183_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/184_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/185_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/186_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/187_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/188_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/189_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/190_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/191_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/192_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/193_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/194_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/195_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/196_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/197_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/198_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/199_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/200_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/201_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/202_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/203_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/204_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/205_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/206_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/207_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/208_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/209_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/210_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/211_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/212_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/213_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/214_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/215_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/216_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/217_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/218_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/219_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/220_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/221_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/222_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/223_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/224_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/225_train.tfrecord',
#  '/data/ssd1/russales/new_records/h36m/226_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp/000_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp/001_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/000_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/001_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/002_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/003_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/004_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/005_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/006_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/007_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/008_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/009_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/010_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/011_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/012_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/013_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/014_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/015_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/016_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/017_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/018_train.tfrecord',
#  '/data/ssd1/russales/new_records/lsp_ext/019_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/000_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/001_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/002_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/003_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/004_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/005_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/006_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/007_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/008_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/009_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/010_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/011_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/012_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/013_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/014_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/015_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/016_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/017_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/018_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/019_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/020_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/021_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/022_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/023_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/024_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/025_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/026_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/027_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/028_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/029_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/030_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/031_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/032_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/033_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/034_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii/035_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/000_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/001_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/002_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/003_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/004_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/005_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/006_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/007_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/008_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/009_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/010_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/011_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/012_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/013_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/014_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/015_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/016_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/017_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/018_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/019_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/020_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/021_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/022_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/023_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/024_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/025_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/026_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/027_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/028_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/029_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/030_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/031_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/032_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/033_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/034_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/035_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/036_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/037_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/038_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/039_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/040_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/041_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/042_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/043_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/044_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/045_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/046_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/047_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/048_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/049_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/050_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/051_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/052_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/053_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/054_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/055_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/056_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/057_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/058_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/059_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/060_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/061_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/062_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/063_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/064_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/065_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/066_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/067_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/068_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/069_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/070_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/071_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/072_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/073_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/074_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/075_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/076_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/077_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/078_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/079_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/080_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/081_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/082_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/083_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/084_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/085_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/086_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/087_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/088_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/089_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/090_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/091_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/092_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/093_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/094_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/095_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/096_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/097_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/098_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/099_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/100_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/101_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/102_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/103_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/104_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/105_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/106_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/107_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/108_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/109_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/110_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/111_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/112_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/113_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/114_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/115_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/116_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/117_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/118_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/119_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/120_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/121_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/122_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/123_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/124_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/125_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/126_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/127_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/128_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/129_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/130_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/131_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/132_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/133_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/134_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/135_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/136_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/137_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/138_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/139_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/140_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/141_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/142_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/143_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/144_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/145_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/146_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/147_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/148_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/149_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/150_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/151_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/152_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/153_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/154_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/155_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/156_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/157_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/158_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/159_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/160_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/161_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/162_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/163_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/164_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/165_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/166_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/167_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/168_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/169_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/170_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/171_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/172_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/173_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/174_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/175_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/176_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/177_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/178_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/179_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/180_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/181_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/182_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/183_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/184_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/185_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/186_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/187_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/188_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/189_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/190_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/191_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/192_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/193_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/194_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/195_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/196_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/197_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/198_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/199_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/200_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/201_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/202_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/203_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/204_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/205_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/206_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/207_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/208_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/209_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/210_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/211_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/212_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/213_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/214_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/215_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/216_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/217_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/218_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/219_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/220_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/221_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/222_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/223_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/224_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/225_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/226_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/227_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/228_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/229_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/230_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/231_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/232_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/233_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/234_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/235_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/236_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/237_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/238_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/239_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/240_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/241_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/242_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/243_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/244_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/245_train.tfrecord',
#  '/data/ssd1/russales/new_records/mpii_3d/246_train.tfrecord',
#  ...]

# %%
# Place tensors on the CPU
with tf.device('/CPU:0'):
    dataset = Dataset()
    ds_train = dataset.get_train()
    ds_smpl = dataset.get_smpl()
    ds_val = dataset.get_val()
# Out:
# initialize train dataset...
# Done (t=1.9709997177124023)
#
# initialize smpl dataset...
# Done (t=0.1956624984741211)
#
# initialize val dataset...
# Done (t=0.38721752166748047)

# %% [markdown]
# ### visualize 2d keypoint data

# %%
def show_image(image, kp2d, vis):
    image = draw_2d_on_image(image, kp2d, vis=vis)
    plt.imshow(image)
    plt.show()

# %%
for images, kp2d, kp3d, has3d in ds_train.take(10):
    kp2d = kp2d[0].numpy()
    image = images[0].numpy()
    show_image(image, kp2d[:, :2], kp2d[:, 2])

# %% [markdown]
# ### visualize 3D keypoint data

# %%
# Visualize random samples
import matplotlib.gridspec as gridspec
# %matplotlib notebook

num_samples = 1

fig = plt.figure(figsize=(9.6, 5.4))
gs = gridspec.GridSpec(num_samples, 3) 
gs.update(wspace=-0.00, hspace=0.05)
plt.axis('off')

subplot_idx = 1
for images, kp2d, kp3d, has3d in ds_train.take(num_samples):
    image = images[0].numpy()
    kp2d = kp2d[0].numpy()
    kp3d = kp3d[0].numpy()
    
    image = draw_2d_on_image(image, kp2d[:, :2], vis=kp2d[:, 2])
    ax0 = plt.subplot(gs[subplot_idx - 1])
    ax0.imshow(image)
    
    ax1 = plt.subplot(gs[subplot_idx], projection='3d')
    show_3d_pose(kp3d, ax1)
    
    ax2 = plt.subplot(gs[subplot_idx + 1])
    show_2d_pose(kp2d[:, :2], kp2d[:, 2], ax2, image.shape[:2])
    
    subplot_idx = subplot_idx + 3
    
    
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="959.2166666666666">

# %% [markdown]
# ### visualize SMPL/Mosh data

# %%
renderer = TrimeshRenderer()
smpl = Smpl()

# %%
meshes = []
for i, theta in enumerate(ds_smpl.take(5)):
    vertices, joints_3d, rotations = smpl(theta)
    mesh = renderer.mesh(vertices[0])
    mesh.apply_translation([i*2,0,0])
    mesh.visual.vertex_colors = trimesh.visual.random_color()
    meshes.append(mesh)

trimesh.Scene(meshes).show()
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <title>trimesh: threejs viewer</title>
#     <meta charset=&quot;utf-8&quot;>
#     <meta name=&quot;viewport&quot; content=&quot;width=device-width,
# 		   user-scalable=no,
# 		   minimum-scale=1.0,
# 		   maximum-scale=1.0&quot;>
#     <style>
#       body {
#       margin: 0px;
#       overflow: hidden;
#       }
#     </style>
#   </head>
#   <body>
#     <div id=&quot;container&quot;></div>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/three.js/109/three.min.js&quot;></script>
#     <script>THREE.TrackballControls=function(object,domElement){var _this=this;var STATE={NONE:-1,ROTATE:0,ZOOM:1,PAN:2,TOUCH_ROTATE:3,TOUCH_ZOOM_PAN:4};this.object=object;this.domElement=(domElement!==undefined)?domElement:document;this.enabled=true;this.screen={left:0,top:0,width:0,height:0};this.rotateSpeed=1.0;this.zoomSpeed=1.2;this.panSpeed=0.3;this.noRotate=false;this.noZoom=false;this.noPan=false;this.staticMoving=false;this.dynamicDampingFactor=0.2;this.minDistance=0;this.maxDistance=Infinity;this.keys=[65 ,83 ,68 ];this.target=new THREE.Vector3();var EPS=0.000001;var lastPosition=new THREE.Vector3();var _state=STATE.NONE,_prevState=STATE.NONE,_eye=new THREE.Vector3(),_movePrev=new THREE.Vector2(),_moveCurr=new THREE.Vector2(),_lastAxis=new THREE.Vector3(),_lastAngle=0,_zoomStart=new THREE.Vector2(),_zoomEnd=new THREE.Vector2(),_touchZoomDistanceStart=0,_touchZoomDistanceEnd=0,_panStart=new THREE.Vector2(),_panEnd=new THREE.Vector2();this.target0=this.target.clone();this.position0=this.object.position.clone();this.up0=this.object.up.clone();var changeEvent={type:'change'};var startEvent={type:'start'};var endEvent={type:'end'};this.handleResize=function(){if(this.domElement===document){this.screen.left=0;this.screen.top=0;this.screen.width=window.innerWidth;this.screen.height=window.innerHeight;}else{var box=this.domElement.getBoundingClientRect();var d=this.domElement.ownerDocument.documentElement;this.screen.left=box.left+window.pageXOffset-d.clientLeft;this.screen.top=box.top+window.pageYOffset-d.clientTop;this.screen.width=box.width;this.screen.height=box.height;}};var getMouseOnScreen=(function(){var vector=new THREE.Vector2();return function getMouseOnScreen(pageX,pageY){vector.set((pageX-_this.screen.left)/_this.screen.width,(pageY-_this.screen.top)/_this.screen.height);return vector;};}());var getMouseOnCircle=(function(){var vector=new THREE.Vector2();return function getMouseOnCircle(pageX,pageY){vector.set(((pageX-_this.screen.width*0.5-_this.screen.left)/(_this.screen.width*0.5)),((_this.screen.height+2*(_this.screen.top-pageY))/_this.screen.width));return vector;};}());this.rotateCamera=(function(){var axis=new THREE.Vector3(),quaternion=new THREE.Quaternion(),eyeDirection=new THREE.Vector3(),objectUpDirection=new THREE.Vector3(),objectSidewaysDirection=new THREE.Vector3(),moveDirection=new THREE.Vector3(),angle;return function rotateCamera(){moveDirection.set(_moveCurr.x-_movePrev.x,_moveCurr.y-_movePrev.y,0);angle=moveDirection.length();if(angle){_eye.copy(_this.object.position).sub(_this.target);eyeDirection.copy(_eye).normalize();objectUpDirection.copy(_this.object.up).normalize();objectSidewaysDirection.crossVectors(objectUpDirection,eyeDirection).normalize();objectUpDirection.setLength(_moveCurr.y-_movePrev.y);objectSidewaysDirection.setLength(_moveCurr.x-_movePrev.x);moveDirection.copy(objectUpDirection.add(objectSidewaysDirection));axis.crossVectors(moveDirection,_eye).normalize();angle*=_this.rotateSpeed;quaternion.setFromAxisAngle(axis,angle);_eye.applyQuaternion(quaternion);_this.object.up.applyQuaternion(quaternion);_lastAxis.copy(axis);_lastAngle=angle;}else if(!_this.staticMoving&&_lastAngle){_lastAngle*=Math.sqrt(1.0-_this.dynamicDampingFactor);_eye.copy(_this.object.position).sub(_this.target);quaternion.setFromAxisAngle(_lastAxis,_lastAngle);_eye.applyQuaternion(quaternion);_this.object.up.applyQuaternion(quaternion);}
# _movePrev.copy(_moveCurr);};}());this.zoomCamera=function(){var factor;if(_state===STATE.TOUCH_ZOOM_PAN){factor=_touchZoomDistanceStart/_touchZoomDistanceEnd;_touchZoomDistanceStart=_touchZoomDistanceEnd;_eye.multiplyScalar(factor);}else{factor=1.0+(_zoomEnd.y-_zoomStart.y)*_this.zoomSpeed;if(factor!==1.0&&factor>0.0){_eye.multiplyScalar(factor);}
# if(_this.staticMoving){_zoomStart.copy(_zoomEnd);}else{_zoomStart.y+=(_zoomEnd.y-_zoomStart.y)*this.dynamicDampingFactor;}}};this.panCamera=(function(){var mouseChange=new THREE.Vector2(),objectUp=new THREE.Vector3(),pan=new THREE.Vector3();return function panCamera(){mouseChange.copy(_panEnd).sub(_panStart);if(mouseChange.lengthSq()){mouseChange.multiplyScalar(_eye.length()*_this.panSpeed);pan.copy(_eye).cross(_this.object.up).setLength(mouseChange.x);pan.add(objectUp.copy(_this.object.up).setLength(mouseChange.y));_this.object.position.add(pan);_this.target.add(pan);if(_this.staticMoving){_panStart.copy(_panEnd);}else{_panStart.add(mouseChange.subVectors(_panEnd,_panStart).multiplyScalar(_this.dynamicDampingFactor));}}};}());this.checkDistances=function(){if(!_this.noZoom||!_this.noPan){if(_eye.lengthSq()>_this.maxDistance*_this.maxDistance){_this.object.position.addVectors(_this.target,_eye.setLength(_this.maxDistance));_zoomStart.copy(_zoomEnd);}
# if(_eye.lengthSq()<_this.minDistance*_this.minDistance){_this.object.position.addVectors(_this.target,_eye.setLength(_this.minDistance));_zoomStart.copy(_zoomEnd);}}};this.update=function(){_eye.subVectors(_this.object.position,_this.target);if(!_this.noRotate){_this.rotateCamera();}
# if(!_this.noZoom){_this.zoomCamera();}
# if(!_this.noPan){_this.panCamera();}
# _this.object.position.addVectors(_this.target,_eye);_this.checkDistances();_this.object.lookAt(_this.target);if(lastPosition.distanceToSquared(_this.object.position)>EPS){_this.dispatchEvent(changeEvent);lastPosition.copy(_this.object.position);}};this.reset=function(){_state=STATE.NONE;_prevState=STATE.NONE;_this.target.copy(_this.target0);_this.object.position.copy(_this.position0);_this.object.up.copy(_this.up0);_eye.subVectors(_this.object.position,_this.target);_this.object.lookAt(_this.target);_this.dispatchEvent(changeEvent);lastPosition.copy(_this.object.position);};function keydown(event){if(_this.enabled===false)return;window.removeEventListener('keydown',keydown);_prevState=_state;if(_state!==STATE.NONE){return;}else if(event.keyCode===_this.keys[STATE.ROTATE]&&!_this.noRotate){_state=STATE.ROTATE;}else if(event.keyCode===_this.keys[STATE.ZOOM]&&!_this.noZoom){_state=STATE.ZOOM;}else if(event.keyCode===_this.keys[STATE.PAN]&&!_this.noPan){_state=STATE.PAN;}}
# function keyup(event){if(_this.enabled===false)return;_state=_prevState;window.addEventListener('keydown',keydown,false);}
# function mousedown(event){if(_this.enabled===false)return;event.preventDefault();event.stopPropagation();if(_state===STATE.NONE){_state=event.button;}
# if(_state===STATE.ROTATE&&!_this.noRotate){_moveCurr.copy(getMouseOnCircle(event.pageX,event.pageY));_movePrev.copy(_moveCurr);}else if(_state===STATE.ZOOM&&!_this.noZoom){_zoomStart.copy(getMouseOnScreen(event.pageX,event.pageY));_zoomEnd.copy(_zoomStart);}else if(_state===STATE.PAN&&!_this.noPan){_panStart.copy(getMouseOnScreen(event.pageX,event.pageY));_panEnd.copy(_panStart);}
# document.addEventListener('mousemove',mousemove,false);document.addEventListener('mouseup',mouseup,false);_this.dispatchEvent(startEvent);}
# function mousemove(event){if(_this.enabled===false)return;event.preventDefault();event.stopPropagation();if(_state===STATE.ROTATE&&!_this.noRotate){_movePrev.copy(_moveCurr);_moveCurr.copy(getMouseOnCircle(event.pageX,event.pageY));}else if(_state===STATE.ZOOM&&!_this.noZoom){_zoomEnd.copy(getMouseOnScreen(event.pageX,event.pageY));}else if(_state===STATE.PAN&&!_this.noPan){_panEnd.copy(getMouseOnScreen(event.pageX,event.pageY));}}
# function mouseup(event){if(_this.enabled===false)return;event.preventDefault();event.stopPropagation();_state=STATE.NONE;document.removeE
