# %% [markdown]
# # Inspect checkpoint wheights

# %%
import sys
print(sys.executable, sys.version)

import cv2
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf 

from glob import glob
from os.path import join, abspath
from IPython.display import display, HTML

# for local import 
sys.path.append(abspath('..'))

from main.config import Config
from main.model import Model
from vis_util import display_weight_stats, display_table
# Out:
# /home/mmc-user/.virtualenvs/hmr2-notebook/bin/python3 3.6.8 (default, Oct  7 2019, 12:59:55)
# [GCC 8.3.0]

# %%
class InspectConfig(Config):
    ENCODER_ONLY = False
    LOG_DIR = join('/', 'data', 'ssd1', 'russales', 'logs', '26042020-171733')
    # RESTORE_PATH = join(LOG_DIR, 'ckpt-6')

# class Config is implemented as singleton, inizialize subclass first!
config = InspectConfig()

# %%
# inizialize model 
model = Model()
# Out:
# Saving logs to /data/ssd1/russales/logs/26042020-171733
#
# Configurations:
# BATCH_SIZE                     64
# DATASETS                       ['lsp', 'lsp_ext', 'coco', 'mpii']
# DATA_DIR                       /data/ssd1/russales/new_records
# DISCRIMINATOR_LEARNING_RATE    0.0001
# DISCRIMINATOR_LOSS_WEIGHT      1
# DISCRIMINATOR_WEIGHT_DECAY     0.0001
# ENCODER_INPUT_SHAPE            (224, 224, 3)
# ENCODER_ONLY                   False
# EPOCHS                         55
# GENERATOR_2D_LOSS_WEIGHT       60.0
# GENERATOR_3D_LOSS_WEIGHT       60.0
# GENERATOR_LEARNING_RATE        1e-05
# GENERATOR_WEIGHT_DECAY         0.0001
# ITERATIONS                     3
# JOINT_TYPE                     cocoplus
# LOG_DIR                        /data/ssd1/russales/logs/26042020-171733
# NUM_CAMERA_PARAMS              3
# NUM_JOINTS                     23
# NUM_JOINTS_GLOBAL              24
# NUM_KP2D                       19
# NUM_KP3D                       14
# NUM_PARALLEL                   16
# NUM_POSE_PARAMS                72
# NUM_SHAPE_PARAMS               10
# NUM_SMPL_PARAMS                85
# NUM_TEST_SAMPLES               0
# NUM_TRAINING_SAMPLES           145121
# NUM_TRAIN_SMPL_SAMPLES         4116233
# NUM_VALIDATION_SAMPLES         5801
# NUM_VERTICES                   6890
# RESTORE_PATH                   None
# ROOT_DATA_DIR                  /data/ssd1/russales
# SCALE_MAX                      1.23
# SCALE_MIN                      0.8
# SEED                           42
# SMPL_DATASETS                  ['cmu', 'joint_lim']
# SMPL_DATA_DIR                  /data/ssd1/russales/new_records/smpl
# SMPL_MEAN_THETA_PATH           /data/ssd1/russales/models/neutral_smpl_mean_params.h5
# SMPL_MODEL_PATH                /data/ssd1/russales/models/neutral_smpl_coco_regressor.pkl
# TRANS_MAX                      20
# USE_3D                         False
# _Config__initialized           True
# _Config__instance              <__main__.InspectConfig object at 0x7f5a782b2550>
#
#
# building model...
#
# Checkpoint restored from /data/ssd1/russales/logs/26042020-171733/ckpt-56

# %%
html = display_weight_stats(model.generator)
display(HTML(html))
# Out:
# <table><tr><td>WEIGHT NAME                             </td><td>SHAPE                                   </td><td>MIN                                     </td><td>MAX                                     </td><td>STD                                     </td></tr><tr><td>conv1_conv/kernel:0                     </td><td>(7, 7, 3, 64)                           </td><td>  -0.5290                               </td><td>   +0.5455                              </td><td>  +0.0991                               </td></tr><tr><td>conv1_conv/bias:0                       </td><td>(64,)                                   </td><td>  -0.0077                               </td><td>   +0.0208                              </td><td>  +0.0068                               </td></tr><tr><td>conv2_block1_preact_bn/gamma:0          </td><td>(64,)                                   </td><td>  +1.6095                               </td><td>   +5.2895                              </td><td>  +0.7875                               </td></tr><tr><td>conv2_block1_preact_bn/beta:0           </td><td>(64,)                                   </td><td>  -5.3990                               </td><td>  +11.3279                              </td><td>  +3.9418                               </td></tr><tr><td>conv2_block1_preact_bn/moving_mean:0    </td><td>(64,)                                   </td><td>  -0.3078                               </td><td>   +1.2905                              </td><td>  +0.3393                               </td></tr><tr><td>conv2_block1_preact_bn/moving_variance:0</td><td>(64,)                                   </td><td>  +0.0067                               </td><td>   +4.1822                              </td><td>  +0.8963                               </td></tr><tr><td>conv2_block1_1_conv/kernel:0            </td><td>(1, 1, 64, 64)                          </td><td>  -0.3247                               </td><td>   +0.2984                              </td><td>  +0.0525                               </td></tr><tr><td>conv2_block1_1_bn/gamma:0               </td><td>(64,)                                   </td><td>  +1.0361                               </td><td>   +2.9146                              </td><td>  +0.3723                               </td></tr><tr><td>conv2_block1_1_bn/beta:0                </td><td>(64,)                                   </td><td>  -6.4986                               </td><td>   +3.0399                              </td><td>  +1.6628                               </td></tr><tr><td>conv2_block1_1_bn/moving_mean:0         </td><td>(64,)                                   </td><td>  -9.7719                               </td><td>  +17.5991                              </td><td>  +4.0358                               </td></tr><tr><td>conv2_block1_1_bn/moving_variance:0     </td><td>(64,)                                   </td><td>  +0.1091                               </td><td>   +9.7067                              </td><td>  +1.5128                               </td></tr><tr><td>conv2_block1_2_conv/kernel:0            </td><td>(3, 3, 64, 64)                          </td><td>  -0.5051                               </td><td>   +0.2950                              </td><td>  +0.0225                               </td></tr><tr><td>conv2_block1_2_bn/gamma:0               </td><td>(64,)                                   </td><td>  +0.7993                               </td><td>   +3.7677                              </td><td>  +0.4999                               </td></tr><tr><td>conv2_block1_2_bn/beta:0                </td><td>(64,)                                   </td><td>  -7.8940                               </td><td>   +4.9556                              </td><td>  +2.2984                               </td></tr><tr><td>conv2_block1_2_bn/moving_mean:0         </td><td>(64,)                                   </td><td>  -3.6600                               </td><td>   +0.9681                   ...

# %%
from tensorflow.python.tools.inspect_checkpoint import print_tensors_in_checkpoint_file

latest_ckp = tf.train.latest_checkpoint(config.LOG_DIR)
print_tensors_in_checkpoint_file(latest_ckp, tensor_name='', all_tensors=True)
