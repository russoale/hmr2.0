# %% [markdown]
# # Inspect TF Records

# %%
import os
import sys
print(sys.executable, sys.version)
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import cv2
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf 

from glob import glob
from os.path import join, abspath
from IPython.display import display, HTML

# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

# for local import 
sys.path.append(abspath('..'))

from main.config import Config
from main.smpl import Smpl
from vis_util import draw_2d_on_image, show_3d_pose
# Out:
# /home/mmc-user/.virtualenvs/hmr2-notebook/bin/python3 3.6.8 (default, Oct  7 2019, 12:59:55)
# [GCC 8.3.0]

# %% [markdown]
# ### parse tf records example proto

# %%
def parse(example_proto):
    feature_map = {
        'image_raw': tf.io.FixedLenFeature([], dtype=tf.string, default_value=''),
        'keypoints_2d': tf.io.VarLenFeature(dtype=tf.float32),
        'keypoints_3d': tf.io.VarLenFeature(dtype=tf.float32),
        'has_3d': tf.io.FixedLenFeature([], dtype=tf.int64)
    }
    features = tf.io.parse_single_example(example_proto, feature_map)

    image = tf.image.decode_image(features['image_raw'], channels=3)
    kp2d = tf.reshape(tf.sparse.to_dense(features['keypoints_2d']), (-1, 3))
    kp3d = tf.reshape(tf.sparse.to_dense(features['keypoints_3d']), (-1, 3))
    has_3d = features['has_3d']

    return image, kp2d, kp3d, has_3d

def parse_test(example_proto):
    feature_map = {
        'image_raw': tf.io.FixedLenFeature([], dtype=tf.string, default_value=''),
        'keypoints_3d': tf.io.VarLenFeature(dtype=tf.float32),
        'keypoints_2d': tf.io.VarLenFeature(dtype=tf.float32),
        'has_3d': tf.io.FixedLenFeature([], dtype=tf.int64),
        'sequence': tf.io.FixedLenFeature([], dtype=tf.string, default_value='NA')
    }
    features = tf.io.parse_single_example(example_proto, feature_map)
    image = tf.image.decode_image(features['image_raw'], channels=3)
    kp2d = tf.reshape(tf.sparse.to_dense(features['keypoints_2d']), (-1, 3))
    kp3d = tf.reshape(tf.sparse.to_dense(features['keypoints_3d']), (-1, 3))
    has_3d = features['has_3d']
    sequence = features['sequence']
    return image, kp2d, kp3d, has_3d, sequence

# %%
def show_image(image, kp2d, vis):
    image = draw_2d_on_image(image, kp2d, vis=vis)
    plt.imshow(image)
    plt.show()

# %% [markdown]
# ### show train/val examples

# %%
def read_train_tfrecords(path):
    dataset = tf.data.TFRecordDataset(path).map(parse).shuffle(500)
    for x in dataset.take(10):
        image, kp2d, kp3d, has_3d = x[0], x[1], x[2], x[3]
        
        print('has3d: ', has_3d.numpy().astype(bool))
        kp2d = kp2d.numpy()
        show_image(image.numpy(), kp2d[:, :2], kp2d[:, 2])

# %%
path = join("/data/ssd1/russales/new_records/mpii_3d", "001_train.tfrecord")
read_train_tfrecords(path)
# Out:
# has3d:  True
# has3d:  True
# has3d:  True
# has3d:  True
# has3d:  True
# has3d:  True
# has3d:  True
# has3d:  True
# has3d:  True
# has3d:  True

# %% [markdown]
# ### show test examples

# %%
def read_test_tfrecords(path):    
    dataset = tf.data.TFRecordDataset(path).map(parse_test)
    for image, kp2d, kp3d, has3d, sequence in dataset.take(10):
        print('sequence: ', sequence.numpy().decode('utf-8'))
        kp2d = kp2d.numpy()
        show_image(image.numpy(), kp2d[:, :2], kp2d[:, 2])

# %%
path = join("/data/ssd1/russales/new_records/mpii_3d", "171_train.tfrecord")
read_test_tfrecords(path)
# Out:
# sequence:  NA
# sequence:  NA
# sequence:  NA
# sequence:  NA
# sequence:  NA
# sequence:  NA
# sequence:  NA
# sequence:  NA
# sequence:  NA
# sequence:  NA

# %%
def read_test_tfrecords_3d(path):    
    dataset = tf.data.TFRecordDataset(path).map(parse_test)
    for image, kp2d, kp3d, has3d, sequence in dataset.take(1):
        print('sequence: ', sequence.numpy().decode('utf-8'))
        kp3d = kp3d.numpy()
        kp2d = kp2d.numpy()
        show_image(image.numpy(), kp2d[:, :2], kp2d[:, 2])    
        
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
        show_3d_pose(kp3d, ax)

# %%
# %matplotlib notebook
read_test_tfrecords_3d(path)
# Out:
# sequence:  mpii_ts1
# <img src="data:image/png;base64,..." width="639.85">
# <img src="data:image/png;base64,..." width="639.85">

# %% [markdown]
# ## Inspect Dataset Splits (train/val/test)

# %%
class CountConfig(Config):
    ROOT_DIR = join('/', 'data', 'ssd1', 'russales')
    DATA_DIR = join(ROOT_DIR, 'new_records')
    DATASETS = ['lsp', 'lsp_ext', 'mpii', 'coco', 'mpii_3d', 'h36m']
    
config = CountConfig()
columns = ['lsp', 'lsp_ext', 'mpii', 'coco', 'mpii_3d', 'h36m']
index = ['# samples', '# 3d samples', '# 2d samples']

# %%
def parse_count(example_proto):
    feature_map = {
        'has_3d': tf.io.FixedLenFeature([], dtype=tf.int64)
    }
    features = tf.io.parse_single_example(example_proto, feature_map)
    has_3d = features['has_3d']
    return has_3d

# %%
def count_train_val_samples(name):
    result = {}
    all_samples, all_3d_samples, all_2d_samples = 0, 0, 0
    for dataset in config.DATASETS:
        tf_records = sorted(glob(join(config.DATA_DIR, dataset, '*_{}.tfrecord'.format(name))))
        if len(tf_records) == 0:
            result[dataset] = [0, 0, 0]
            print("done:", dataset)
            continue
            
        ds = tf.data.TFRecordDataset(tf_records, num_parallel_reads=config.NUM_PARALLEL) \
            .map(parse_count, num_parallel_calls=config.NUM_PARALLEL) \
            .batch(config.BATCH_SIZE, drop_remainder=False) \
            .prefetch(config.BATCH_SIZE * 2)
        
        samples, ds_3d_samples, ds_2d_samples = 0, 0, 0
        for has_3d in ds:
            has_3d = has_3d.numpy()
            count_3d = np.sum(has_3d)
            ds_3d_samples = ds_3d_samples + count_3d
            ds_2d_samples = ds_2d_samples + (has_3d.size - count_3d)
            samples = samples + has_3d.size
        
        all_samples = all_samples + samples
        all_3d_samples = all_3d_samples + ds_3d_samples
        all_2d_samples = all_2d_samples + ds_2d_samples
        
        result[dataset] = [samples, ds_3d_samples, ds_2d_samples]
        print("done:", dataset)
        
    print('\nTotal number of {} samples: {}'.format("train", all_samples))
    print('3d samples: {} - 2d samples: {}'.format(all_3d_samples, all_2d_samples))

    df = pd.DataFrame(result, index=index, columns=columns)
    df = df.astype('int32')
    display(HTML(df.to_html()))

# %%
count_train_val_samples('train')
# Out:
# done: lsp
# done: lsp_ext
# done: mpii
# done: coco
# done: mpii_3d
# done: h36m
#
# Total number of train samples: 425334
# 3d samples: 280213 - 2d samples: 145121
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>lsp</th>
#       <th>lsp_ext</th>
#       <th>mpii</th>
#       <th>coco</th>
#       <th>mpii_3d</th>
#       <th>h36m</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th># samples</th>
#       <td>999</td>
#       <td>9984</td>
#       <td>17537</td>
#       <td>116601</td>
#       <td>166982</td>
#       <td>113231</td>
#     </tr>
#     <tr>
#       <th># 3d samples</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>166982</td>
#       <td>113231</td>
#     </tr>
#     <tr>
#       <th># 2d samples</th>
#       <td>999</td>
#       <td>9984</td>
#       <td>17537</td>
#       <td>116601</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>

# %%
count_train_val_samples('val')
# Out:
# done: lsp
# done: lsp_ext
# done: mpii
# done: coco
# done: mpii_3d
# done: h36m
#
# Total number of train samples: 11921
# 3d samples: 6120 - 2d samples: 5801
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>lsp</th>
#       <th>lsp_ext</th>
#       <th>mpii</th>
#       <th>coco</th>
#       <th>mpii_3d</th>
#       <th>h36m</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th># samples</th>
#       <td>999</td>
#       <td>0</td>
#       <td>0</td>
#       <td>4802</td>
#       <td>0</td>
#       <td>6120</td>
#     </tr>
#     <tr>
#       <th># 3d samples</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>6120</td>
#     </tr>
#     <tr>
#       <th># 2d samples</th>
#       <td>999</td>
#       <td>0</td>
#       <td>0</td>
#       <td>4802</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>

# %%
def count_test_samples():
    config = CountConfig()

    tf_record_dirs = [join(config.DATA_DIR, dataset, '*_test.tfrecord') for dataset in config.DATASETS]
    tf_records = [tf_record for tf_records in sorted([glob(f) for f in tf_record_dirs]) for tf_record in tf_records]
    
    def parse_test(example_proto):
        feature_map = {
            'sequence': tf.io.FixedLenFeature([], dtype=tf.string)
        }
        features = tf.io.parse_single_example(example_proto, feature_map)
        sequence = features['sequence']
        return sequence

    dataset = tf.data.TFRecordDataset(tf_records, num_parallel_reads=config.NUM_PARALLEL) \
        .map(parse_test, num_parallel_calls=config.NUM_PARALLEL) \
        .prefetch(config.NUM_PARALLEL * 2)
    
    num_samples, sequence_count = 0, {}
    for sequence in dataset:
        sequence = sequence.numpy().decode("utf-8")
        if sequence not in sequence_count.keys():
            sequence_count[sequence] = 1
        else:
            sequence_count[sequence] += 1
        num_samples += 1

    print('Total number of samples in tf records: ', num_samples)

    return json.dumps(sequence_count, indent=4, sort_keys=True)

# %%
data_test = count_test_samples()

df_test = pd.read_json(data_test, orient='index')
display(HTML(df_test.to_html()))
# Out:
# Total number of samples in tf records:  42369
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>h36m_sub11_Directions 1_cam54138969</th>
#       <td>59</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Directions 1_cam55011271</th>
#       <td>59</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Directions 1_cam58860488</th>
#       <td>59</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Directions 1_cam60457274</th>
#       <td>59</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Directions_cam54138969</th>
#       <td>69</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Directions_cam55011271</th>
#       <td>69</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Directions_cam58860488</th>
#       <td>69</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Directions_cam60457274</th>
#       <td>69</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Discussion 1_cam54138969</th>
#       <td>104</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Discussion 1_cam55011271</th>
#       <td>104</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Discussion 1_cam58860488</th>
#       <td>105</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Discussion 1_cam60457274</th>
#       <td>104</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Discussion 2_cam54138969</th>
#       <td>109</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Discussion 2_cam55011271</th>
#       <td>109</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Discussion 2_cam58860488</th>
#       <td>109</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Discussion 2_cam60457274</th>
#       <td>109</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Eating 1_cam54138969</th>
#       <td>144</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Eating 1_cam55011271</th>
#       <td>144</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Eating 1_cam58860488</th>
#       <td>144</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Eating 1_cam60457274</th>
#       <td>144</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Eating_cam54138969</th>
#       <td>152</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Eating_cam55011271</th>
#       <td>152</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Eating_cam58860488</th>
#       <td>152</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Eating_cam60457274</th>
#       <td>152</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Greeting 2_cam54138969</th>
#       <td>134</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Greeting 2_cam55011271</th>
#       <td>134</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Greeting 2_cam58860488</th>
#       <td>133</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Greeting 2_cam60457274</th>
#       <td>134</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Greeting_cam54138969</th>
#       <td>139</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Greeting_cam55011271</th>
#       <td>139</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Greeting_cam58860488</th>
#       <td>139</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Greeting_cam60457274</th>
#       <td>139</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Phoning 2_cam54138969</th>
#       <td>198</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Phoning 2_cam55011271</th>
#       <td>198</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Phoning 2_cam58860488</th>
#       <td>199</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Phoning 2_cam60457274</th>
#       <td>198</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Phoning 3_cam54138969</th>
#       <td>233</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Phoning 3_cam55011271</th>
#       <td>233</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Phoning 3_cam58860488</th>
#       <td>233</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Phoning 3_cam60457274</th>
#       <td>233</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Photo 1_cam54138969</th>
#       <td>89</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Photo 1_cam55011271</th>
#       <td>89</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Photo 1_cam58860488</th>
#       <td>89</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Photo 1_cam60457274</th>
#       <td>89</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Photo_cam54138969</th>
#       <td>110</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Photo_cam55011271</th>
#       <td>110</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Photo_cam58860488</th>
#       <td>110</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Photo_cam60457274</th>
#       <td>110</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Posing 1_cam54138969</th>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Posing 1_cam55011271</th>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Posing 1_cam58860488</th>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Posing 1_cam60457274</th>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Posing_cam54138969</th>
#       <td>58</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Posing_cam55011271</th>
#       <td>58</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Posing_cam58860488</th>
#       <td>58</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Posing_cam60457274</th>
#       <td>58</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Purchases 1_cam54138969</th>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Purchases 1_cam55011271</th>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Purchases 1_cam58860488</th>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Purchases 1_cam60457274</th>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Purchases_cam54138969</th>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Purchases_cam55011271</th>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Purchases_cam58860488</th>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Purchases_cam60457274</th>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Sitting 1_cam54138969</th>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Sitting 1_cam55011271</th>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Sitting 1_cam58860488</th>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Sitting 1_cam60457274</th>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_SittingDown 1_cam54138969</th>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_SittingDown 1_cam55011271</th>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_SittingDown 1_cam58860488</th>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_SittingDown 1_cam60457274</th>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_SittingDown_cam54138969</th>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_SittingDown_cam55011271</th>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_SittingDown_cam58860488</th>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_SittingDown_cam60457274</th>
#       <td>69</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Sitting_cam54138969</th>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Sitting_cam55011271</th>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Sitting_cam58860488</th>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Sitting_cam60457274</th>
#       <td>75</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Smoking 2_cam54138969</th>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Smoking 2_cam55011271</th>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Smoking 2_cam58860488</th>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Smoking 2_cam60457274</th>
#       <td>130</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Smoking_cam54138969</th>
#       <td>164</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Smoking_cam55011271</th>
#       <td>164</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Smoking_cam58860488</th>
#       <td>164</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Smoking_cam60457274</th>
#       <td>164</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Waiting 1_cam54138969</th>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Waiting 1_cam55011271</th>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Waiting 1_cam58860488</th>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>h36m_sub11_Waiting 1_cam60457274</th>
#       <td>60</td>

# %% [markdown]
# ### inspect visible keypoints 2d

# %%
def count_train_kp2d_samples():
    config = CountConfig()
    
    def parse_kp2d(example_proto):
        feature_map = {
            'keypoints_2d': tf.io.VarLenFeature(dtype=tf.float32),
        }
        features = tf.io.parse_single_example(example_proto, feature_map)
        kp2d = tf.reshape(tf.sparse.to_dense(features['keypoints_2d']), (-1, 3))
        return kp2d
    
    result = {}
    for dataset in config.DATASETS:
        tf_records = sorted([glob(join(config.DATA_DIR, dataset, '*_train.tfrecord'))])
        
        ds = tf.data.TFRecordDataset(tf_records, num_parallel_reads=config.NUM_PARALLEL) \
            .map(parse_kp2d, num_parallel_calls=config.NUM_PARALLEL) \
            .batch(config.BATCH_SIZE) \
            .prefetch(config.BATCH_SIZE * 2)
        
        idx = range(19)
        vis_kps = np.ndarray((19,))
        for kp2d in ds:
            kp2d = kp2d.numpy()
            kps = np.transpose(kp2d, (1, 0, 2))
            for i, kp in zip(idx, kps):
                vis_kps[i] = vis_kps[i] + max(np.sum(kp[:, 2]), 0)
            
        print("done:", dataset)
        result[dataset] = vis_kps
        
    return result

# %%
columns_kp2d = ['lsp', 'lsp_ext', 'mpii', 'coco', 'mpii_3d', 'h36m']
coco_kp2d = ['ankle_r', 'knee_r', 'hip_r', 'hip_l', 'knee_l', 'ankle_l', 'wrist_r', 'elbow_r', 'shoulder_r', 
            'shoulder_l', 'elbow_l', 'wrist_l', 'neck', 'brain', 'nose', 'eye_l', 'eye_r', 'ear_l', 'ear_r']

data_kp2d = count_train_kp2d_samples()

df_kp2d = pd.DataFrame(data_kp2d, index=coco_kp2d, columns=columns_kp2d)
df_kp2d = df_kp2d.astype('int32')
display(HTML(df_kp2d.to_html()))

# if following error occurs just run again
# Cannot convert non-finite values (NA or inf) to integer
# Out:
# done: lsp
# done: lsp_ext
# done: mpii
# done: coco
# done: mpii_3d
# done: h36m
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>lsp</th>
#       <th>lsp_ext</th>
#       <th>mpii</th>
#       <th>coco</th>
#       <th>mpii_3d</th>
#       <th>h36m</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ankle_r</th>
#       <td>982</td>
#       <td>8902</td>
#       <td>10342</td>
#       <td>58756</td>
#       <td>166982</td>
#       <td>113231</td>
#     </tr>
#     <tr>
#       <th>knee_r</th>
#       <td>979</td>
#       <td>9171</td>
#       <td>12614</td>
#       <td>72183</td>
#       <td>166982</td>
#       <td>113231</td>
#     </tr>
#     <tr>
#       <th>hip_r</th>
#       <td>959</td>
#       <td>8462</td>
#       <td>13229</td>
#       <td>87803</td>
#       <td>166982</td>
#       <td>113231</td>
#     </tr>
#     <tr>
#       <th>hip_l</th>
#       <td>924</td>
#       <td>8274</td>
#       <td>13396</td>
#       <td>88146</td>
#       <td>166982</td>
#       <td>113231</td>
#     </tr>
#     <tr>
#       <th>knee_l</th>
#       <td>961</td>
#       <td>9106</td>
#       <td>12683</td>
#       <td>72183</td>
#       <td>166982</td>
#       <td>113231</td>
#     </tr>
#     <tr>
#       <th>ankle_l</th>
#       <td>957</td>
#       <td>8948</td>
#       <td>10320</td>
#       <td>58880</td>
#       <td>166982</td>
#       <td>113231</td>
#     </tr>
#     <tr>
#       <th>wrist_r</th>
#       <td>884</td>
#       <td>8901</td>
#       <td>14052</td>
#       <td>80797</td>
#       <td>166982</td>
#       <td>113231</td>
#     </tr>
#     <tr>
#       <th>elbow_r</th>
#       <td>920</td>
#       <td>8871</td>
#       <td>14485</td>
#       <td>86793</td>
#       <td>166982</td>
#       <td>113231</td>
#     </tr>
#     <tr>
#       <th>shoulder_r</th>
#       <td>913</td>
#       <td>8737</td>
#       <td>14185</td>
#       <td>105044</td>
#       <td>166982</td>
#       <td>113231</td>
#     </tr>
#     <tr>
#       <th>shoulder_l</th>
#       <td>830</td>
#       <td>8594</td>
#       <td>14074</td>
#       <td>105824</td>
#       <td>166982</td>
#       <td>113231</td>
#     </tr>
#     <tr>
#       <th>elbow_l</th>
#       <td>850</td>
#       <td>8709</td>
#       <td>14311</td>
#       <td>86159</td>
#       <td>166982</td>
#       <td>113231</td>
#     </tr>
#     <tr>
#       <th>wrist_l</th>
#       <td>851</td>
#       <td>8790</td>
#       <td>13838</td>
#       <td>79101</td>
#       <td>166982</td>
#       <td>113231</td>
#     </tr>
#     <tr>
#       <th>neck</th>
#       <td>993</td>
#       <td>8096</td>
#       <td>0</td>
#       <td>0</td>
#       <td>166982</td>
#       <td>113231</td>
#     </tr>
#     <tr>
#       <th>brain</th>
#       <td>996</td>
#       <td>9539</td>
#       <td>0</td>
#       <td>0</td>
#       <td>166982</td>
#       <td>113231</td>
#     </tr>
#     <tr>
#       <th>nose</th>
#       <td>0</td>
#       <td>0</td>
#       <td>10527</td>
#       <td>84878</td>
#       <td>166982</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>eye_l</th>
#       <td>0</td>
#       <td>0</td>
#       <td>10827</td>
#       <td>76264</td>
#       <td>166982</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>eye_r</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>76269</td>
#       <td>166982</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>ear_l</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>62737</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>ear_r</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>61802</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_kp2d.to_csv('dataset_kps.csv')

# %% [markdown]
# ### inspect smpl/mosh data

# %%
def parse_smpl(example_proto):
    feature_map = {
        'pose': tf.io.VarLenFeature(dtype=tf.float32),
        'shape': tf.io.VarLenFeature(dtype=tf.float32),
    }
    features = tf.io.parse_single_example(example_proto, feature_map)
    pose = tf.reshape(tf.sparse.to_dense(features['pose']), (config.NUM_POSE_PARAMS,))
    shape = tf.reshape(tf.sparse.to_dense(features['shape']), (config.NUM_SHAPE_PARAMS,))

    return tf.concat([tf.zeros(3), pose, shape], axis=-1)  # fake cam, pose and shape

# %%
def count_train_smpl_samples():
    config = CountConfig()
    
    result = {}
    for dataset in config.SMPL_DATASETS:
        tf_records = sorted([glob(join(config.SMPL_DATA_DIR, dataset, '*_train.tfrecord'))])
        
        ds = tf.data.TFRecordDataset(tf_records, num_parallel_reads=config.NUM_PARALLEL) \
            .map(parse_smpl, num_parallel_calls=config.NUM_PARALLEL) \
            .batch(config.BATCH_SIZE) \
            .prefetch(config.BATCH_SIZE * 2)

        num_smpl = 0
        for smpl in ds:
            num_smpl += smpl.numpy().shape[0]
            
        print("done:", dataset)
        result[dataset] = num_smpl
        
    return result

# %%
columns_smpl = ['cmu', 'joint_lim']
index_smpl = ['# samples']

data_smpl = count_train_smpl_samples()

df_smpl = pd.DataFrame(data_smpl, index=index_smpl, columns=columns_smpl)
df_smpl = df_smpl.astype('int32')
display(HTML(df_smpl.to_html()))
# Out:
# done: cmu
# done: joint_lim
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cmu</th>
#       <th>joint_lim</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th># samples</th>
#       <td>3934266</td>
#       <td>181967</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### serialize example proto

# %%
def print_example(path):
    raw_dataset = tf.data.TFRecordDataset([path])

    for raw_record in raw_dataset.take(1):
        example = tf.train.Example()
        example.ParseFromString(raw_record.numpy())
        print(example)

# %%
path = os.path.join("/data/ssd1/russales/new_records/mpii_3d", "347_test.tfrecord")
print_example(path)
# Out:
# features {
#   feature {
#     key: "has_3d"
#     value {
#       int64_list {
#         value: 1
#       }
#     }
#   }
#   feature {
#     key: "image_raw"
#     value {
#       bytes_list {
#         value: "\377\330\377\340\000\020JFIF\000\001\001\000\000\001\000\001\000\000\377\333\000C\000\002\001\001\001\001\001\002\001\001\001\002\002\002\002\002\004\003\002\002\002\002\005\004\004\003\004\006\005\006\006\006\005\006\006\006\007\t\010\006\007\t\007\006\006\010\013\010\t\n\n\n\n\n\006\010\013\014\013\n\014\t\n\n\n\377\333\000C\001\002\002\002\002\002\002\005\003\003\005\n\007\006\007\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\377\300\000\021\010\001\016\001\024\003\001\"\000\002\021\001\003\021\001\377\304\000\037\000\000\001\005\001\001\001\001\001\001\000\000\000\000\000\000\000\000\001\002\003\004\005\006\007\010\t\n\013\377\304\000\265\020\000\002\001\003\003\002\004\003\005\005\004\004\000\000\001}\001\002\003\000\004\021\005\022!1A\006\023Qa\007\"q\0242\201\221\241\010#B\261\301\025R\321\360$3br\202\t\n\026\027\030\031\032%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\203\204\205\206\207\210\211\212\222\223\224\225\226\227\230\231\232\242\243\244\245\246\247\250\251\252\262\263\264\265\266\267\270\271\272\302\303\304\305\306\307\310\311\312\322\323\324\325\326\327\330\331\332